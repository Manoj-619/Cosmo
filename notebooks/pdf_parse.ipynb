# %%
pip install pdfplumber

# %% [markdown]
# For PDF link

# %%
import pdfplumber
import pandas as pd
from pathlib import Path
import openpyxl
import re

def remove_illegal_characters(text):
    """
    Remove characters that are not allowed in Excel.
    """
    ILLEGAL_CHARACTERS_RE = re.compile(r'[\x00-\x08\x0B\x0C\x0E-\x1F]')
    return ILLEGAL_CHARACTERS_RE.sub('', text)


def clean_text(text):
    """
    Clean text by removing extra spaces and newlines
    """
    return ' '.join(text.split())

def find_section(text, section):
    """
    Find section considering possible line breaks and variations
    Returns the index of the section if found, -1 otherwise
    """
    if section == "Key words":
        idx = text.find("Key words")
        if idx != -1:
            return idx
        idx = text.find("Keywords")
        if idx != -1:
            return idx
    
    idx = text.find(section)
    if idx != -1:
        return idx
    
    section_space = ' '.join(section.split())
    idx = text.find(section_space)
    if idx != -1:
        return idx
    
    parts = section.split()
    if len(parts) > 1:
        first_part = parts[0]
        idx = text.find(first_part)
        if idx != -1:
            next_text = text[idx:idx+len(section)+10]
            next_text_clean = clean_text(next_text)
            if section_space in next_text_clean:
                return idx
    
    return -1

def extract_sections_from_pdf(pdf_path, sections):
    """
    Extract sections from PDF using a simple linear search approach.
    Handles multi-line section headers.
    """
    extracted_sections = {section: "" for section in sections}
    
    try:
        with pdfplumber.open(pdf_path) as pdf:
            text = " ".join([page.extract_text() for page in pdf.pages])
            text = clean_text(text)
            
            for i, section in enumerate(sections):
                start_idx = find_section(text, section)
                if start_idx != -1:
                    if section == "Key words" and text[start_idx:start_idx+8] == "Keywords":
                        content_start = start_idx + 8
                    else:
                        content_start = start_idx + len(section)
                    
                    content_end = len(text)
                    for next_section in sections[i+1:]:
                        next_idx = find_section(text, next_section)
                        if next_idx != -1:
                            content_end = next_idx
                            break
                    
                    content = text[content_start:content_end].strip()
                    extracted_sections[section] = remove_illegal_characters(content)

    
    except Exception as e:
        print(f"Error reading PDF: {str(e)} in file: {pdf_path}")  
        return None
    
    return extracted_sections

def process_pdfs_to_excel(pdf_folder, output_excel, sections, num_files=None):
    """
    Process PDFs in a folder and create an Excel file.
    """
    pdf_files = list(Path(pdf_folder).glob('*.pdf'))
    if num_files:
        pdf_files = pdf_files[:num_files]
    
    all_data = []
    total_files = len(pdf_files)
    
    print(f"Processing {total_files} files...")
    
    for i, pdf_file in enumerate(pdf_files, 1):
        if i % 400 == 0 or i == total_files:
            print(f"Processing ({i}/{total_files}) files...")
        
        sections_data = extract_sections_from_pdf(pdf_file, sections)
        
        if sections_data:
            sections_data['Filename'] = pdf_file.name
            all_data.append(sections_data)
    
    if not all_data:
        print("No data was successfully extracted from any PDF.")
        return
    
    df = pd.DataFrame(all_data)
    
    for col in ['Filename'] + sections:
        if col not in df.columns:
            df[col] = ""
    
    columns = ['Filename'] + sections
    df = df[columns]
    
    df.to_excel(output_excel, index=False)
    print(f"\nProcessed {len(all_data)} files successfully")
    print(f"Saved to: {output_excel}")
    return df

sections = [
    "Overview",
    "Performance criteria",
    "Knowledge and understanding",
    "Additional Information",
    "Developed by",
    "Key words"  
]

pdf_folder = r"C:\\Users\\amith\\Kenpath\\NOS"
output_excel = r"C:\\Users\\amith\\Kenpath\\parsed_nos.xlsx"
df=process_pdfs_to_excel(pdf_folder, output_excel, sections)
# Out:
# Processing 15295 files...
# Processing (400/15295) files...
# Error reading PDF: Unexpected EOF in file: C:\Users\amith\Kenpath\NOS\Apply_species_identification_skills__Legacy.pdf
# Processing (800/15295) files...
# Processing (1200/15295) files...
# Processing (1600/15295) files...
# Error reading PDF: Unexpected EOF in file: C:\Users\amith\Kenpath\NOS\Carry_out_tremie_operations.pdf
# Processing (2000/15295) files...
# Processing (2400/15295) files...
# Processing (2800/15295) files...
# Error reading PDF: Unexpected EOF in file: C:\Users\amith\Kenpath\NOS\Contribute_to_the_management_of_finances_for_properties_in_England,_Wales_and_Northern_Ireland.pdf
# Processing (3200/15295) files...
# Processing (3600/15295) files...
# Data-loss while decompressing corrupted data
# Processing (4000/15295) files...
# Processing (4400/15295) files...
# Processing (4800/15295) files...
# Error reading PDF: Unexpected EOF in file: C:\Users\amith\Kenpath\NOS\Engage_participants_in_community_arts_activities_.pdf
# Error reading PDF: Unexpected EOF in file: C:\Users\amith\Kenpath\NOS\Erect_fire_resisting_walls_and_wall_linings.pdf
# Processing (5200/15295) files...
# Processing (5600/15295) files...
# Processing (6000/15295) files...
# Error reading PDF: Unexpected EOF in file: C:\Users\amith\Kenpath\NOS\Identify_opportunities_to_increase_retail_sales_of_particular_products_Legacy.pdf
# [WARNING] Metadata key "P" could not be parsed due to exception: maximum recursion depth exceeded
# Processing (6400/15295) files...
# Processing (6800/15295) files...
# Processing (7200/15295) files...
# Processing (7600/15295) files...
# Error reading PDF: Unexpected EOF in file: C:\Users\amith\Kenpath\NOS\Maintain_an_asset_register_and_service_history_information_in_healthcare.pdf
# Data-loss while decompressing corrupted data
# Error reading PDF: Unexpected EOF in file: C:\Users\amith\Kenpath\NOS\Maintain_the_performance_of_electronic_security_systems_LEGACY.pdf
# [WARNING] Metadata key "K" could not be parsed due to exception: maximum recursion depth exceeded
# [WARNING] Metadata key "P" could not be parsed due to exception: maximum recursion depth exceeded
# Processing (8000/15295) files...
# Error reading PDF: Unexpected EOF in file: C:\Users\amith\Kenpath\NOS\Make_sure_your_own_actions_reduce_risks_to_health_and_safety_Legacy.pdf
# Processing (8400/15295) files...
# Error reading PDF: Unexpected EOF in file: C:\Users\amith\Kenpath\NOS\Manage_relationships_during_change_management_programmes_for_IT_enabled_systems.pdf
# Data-loss while decompressing corrupted data
# Processing (8800/15295) files...
# Processing (9200/15295) files...
# Error reading PDF: Unexpected EOF in file: C:\Users\amith\Kenpath\NOS\Optimise_and_control_contract_progress_and_costs_in_construction_contracting_operations_management_Legacy.pdf
# Processing (9600/15295) files...
# Data-loss while decompressing corrupted data
# Processing (10000/15295) files...
# Processing (10400/15295) files...
# Error reading PDF: Unexpected EOF in file: C:\Users\amith\Kenpath\NOS\Prepare_for_and_carry_out_industrial_pressure_cleaning_operations.pdf
# Error reading PDF: Unexpected EOF in file: C:\Users\amith\Kenpath\NOS\Prepare_raw_materials_and_equipment_for_processing.pdf
# Processing (10800/15295) files...
# Error reading PDF: Unexpected EOF in file: C:\Users\amith\Kenpath\NOS\Process_applications_for_membership_to_a_collecting_society.pdf
# Processing (11200/15295) files...
# Processing (11600/15295) files...
# Processing (12000/15295) files...
# Processing (12400/15295) files...
# Processing (12800/15295) files...
# Processing (13200/15295) files...
# Processing (13600/15295) files...
# Error reading PDF: Unexpected EOF in file: C:\Users\amith\Kenpath\NOS\Support_children_and_young_people_through_major_transitions_.pdf
# Error reading PDF: Unexpected EOF in file: C:\Users\amith\Kenpath\NOS\Support_children’s_play_and_learning.pdf
# Processing (14000/15295) files...
# Processing (14400/15295) files...
# Processing (14800/15295) files...
# Data-loss while decompressing corrupted data
# Error reading PDF: Unexpected EOF in file: C:\Users\amith\Kenpath\NOS\Work_safely_and_follow_reporting_procedures.pdf
# Processing (15200/15295) files...
# Processing (15295/15295) files...
#
# Processed 15278 files successfully
# Saved to: C:\\Users\\amith\\Kenpath\\parsed_nos.xlsx

# %% [markdown]
# For WEB Link

# %%
import pdfplumber
import pandas as pd
from pathlib import Path
import openpyxl
import re

def remove_illegal_characters(text):
    """
    Remove characters that are not allowed in Excel.
    """
    ILLEGAL_CHARACTERS_RE = re.compile(r'[\x00-\x08\x0B\x0C\x0E-\x1F]')
    return ILLEGAL_CHARACTERS_RE.sub('', text)


def clean_text(text):
    """
    Clean text by removing extra spaces and newlines
    """
    return ' '.join(text.split())

def find_section(text, section):
    """
    Find section considering possible line breaks and variations
    Returns the index of the section if found, -1 otherwise
    """
    # Handle "Key words" variations
    if section == "Key words":
        idx = text.find("Key words")
        if idx != -1:
            return idx
        idx = text.find("Keywords")
        if idx != -1:
            return idx
            
    # Handle "Additional Information" variations
    if section == "Additional Information":
        variations = [
            "Additional Information",
            "Behaviors",
            "Glossary",
            "Scope/range related to performance criteria",
            "Scope/range",
            "Skills",
            "Scope/range related to knowledge and understanding"
        ]
        # Find the earliest occurrence of any variation
        indices = []
        for variation in variations:
            idx = text.find(variation)
            if idx != -1:
                indices.append(idx)
        
        # Return the earliest index if any variation was found
        if indices:
            return min(indices)
    
    # Original section name
    idx = text.find(section)
    if idx != -1:
        return idx
    
    # Try with space instead of newline
    section_space = ' '.join(section.split())
    idx = text.find(section_space)
    if idx != -1:
        return idx
    
    # Try with parts of split sections
    parts = section.split()
    if len(parts) > 1:
        # Try finding first part followed by second part with possible line break
        first_part = parts[0]
        idx = text.find(first_part)
        if idx != -1:
            # Check if next part follows within reasonable distance
            next_text = text[idx:idx+len(section)+10]  # Add some buffer for line breaks
            next_text_clean = clean_text(next_text)
            if section_space in next_text_clean:
                return idx
    
    return -1

def extract_sections_from_pdf(pdf_path, sections):
    """
    Extract sections from PDF using a simple linear search approach.
    Handles multi-line section headers.
    """
    extracted_sections = {section: "" for section in sections}
    
    try:
        with pdfplumber.open(pdf_path) as pdf:
            text = " ".join([page.extract_text() for page in pdf.pages])
            text = clean_text(text)
            
            for i, section in enumerate(sections):
                start_idx = find_section(text, section)
                if start_idx != -1:
                    if section == "Key words" and text[start_idx:start_idx+8] == "Keywords":
                        content_start = start_idx + 8
                    else:
                        content_start = start_idx + len(section)
                    
                    content_end = len(text)
                    for next_section in sections[i+1:]:
                        next_idx = find_section(text, next_section)
                        if next_idx != -1:
                            content_end = next_idx
                            break
                    
                    content = text[content_start:content_end].strip()
                    extracted_sections[section] = remove_illegal_characters(content)

    
    except Exception as e:
        print(f"Error reading PDF: {str(e)} in file: {pdf_path}")  
        return None
    
    return extracted_sections

def process_pdfs_to_excel(pdf_folder, output_excel, sections, num_files=None):
    """
    Process PDFs in a folder and create an Excel file.
    """
    pdf_files = list(Path(pdf_folder).glob('*.pdf'))
    if num_files:
        pdf_files = pdf_files[:num_files]
    
    all_data = []
    total_files = len(pdf_files)
    
    print(f"Processing {total_files} files...")
    
    for i, pdf_file in enumerate(pdf_files, 1):
        if i % 400 == 0 or i == total_files:
            print(f"Processing ({i}/{total_files}) files...")
        
        sections_data = extract_sections_from_pdf(pdf_file, sections)
        
        if sections_data:
            sections_data['Filename'] = pdf_file.name
            all_data.append(sections_data)
    
    if not all_data:
        print("No data was successfully extracted from any PDF.")
        return
    
    df = pd.DataFrame(all_data)
    
    for col in ['Filename'] + sections:
        if col not in df.columns:
            df[col] = ""
    
    columns = ['Filename'] + sections
    df = df[columns]
    
    df.to_excel(output_excel, index=False)
    print(f"\nProcessed {len(all_data)} files successfully")
    print(f"Saved to: {output_excel}")
    return df

sections = [
    "Overview",
    "Performance criteria",
    "Knowledge and understanding",
    "Additional Information",
    "Developed by",
    "Key words"  
]

pdf_folder = r"C:\Users\amith\Kenpath\NOS from web"
output_excel = r"C:\\Users\\amith\\Kenpath\\parsed_nos(web).xlsx"
df=process_pdfs_to_excel(pdf_folder, output_excel, sections)
# Out:
# Processing 7360 files...
# Processing (400/7360) files...
# Processing (800/7360) files...
# Processing (1200/7360) files...
# Processing (1600/7360) files...
# Processing (2000/7360) files...
# Processing (2400/7360) files...
# Processing (2800/7360) files...
# Processing (3200/7360) files...
# Processing (3600/7360) files...
# Processing (4000/7360) files...
# Processing (4400/7360) files...
# Processing (4800/7360) files...
# Processing (5200/7360) files...
# Processing (5600/7360) files...
# Processing (6000/7360) files...
# Processing (6400/7360) files...
# Processing (6800/7360) files...
# Processing (7200/7360) files...
# Processing (7360/7360) files...
#
# Processed 7360 files successfully
# Saved to: C:\\Users\\amith\\Kenpath\\parsed_nos(web).xlsx

# %%
import pandas as pd

# Load the first Excel file
df1 = pd.read_excel("C:\\Users\\amith\\Kenpath\\parsed_nos(pdf).xlsx")

# Load the second Excel file
df2 = pd.read_excel("C:\\Users\\amith\\Kenpath\\parsed_nos(web).xlsx")

# %%
df1
# Out:
#                                                 Filename  \
# 0            2D_Drawing_and_planning_software_LEGACY.pdf
# 1      Abrasive_wheel_operations_in_the_wood_industry...
# 2      Accept,_and_return,_responsibility_for_the_con...
# 3      Accept,_verify_and_store_materials_required_fo...
# 4      Acceptance_test_products,_equipment,_medical_d...
# ...                                                  ...
# 15273  Write_technical_content_for_inclusion_in_nucle...
# 15274  Write_text-based_material_for_multi-platform_u...
# 15275    Write_varied_text_on_a_range_of_work_topics.pdf
# 15276                         Writing_a_design_brief.pdf
# 15277           Writing_laboratory_technical_reports.pdf
#
#                                                 Overview  \
# 0                                                    NaN
# 1      This standard covers the skills and knowledge ...
# 2      This unit is about accepting and returning res...
# 3      This unit is for those with responsibility for...
# 4      This standard relates to the critical examinat...
# ...                                                  ...
# 15273  This unit is about activity in the production ...
# 15274  This standard is about writing text-based mate...
# 15275  You can write text (1-3 pages) for work and so...
# 15276  This unit is about writing a design brief and ...
# 15277  This unit covers the competences you need to w...
#
#                                     Performance criteria  \
# 0                                                    NaN
# 1      You must be able to: 1. carry out risk assessm...
# 2      You must be able to: P1 work safely at all tim...
# 3      You must be able to: P1 work safely at all tim...
# 4      You must be able to: P1 work within your level...
# ...                                                  ...
# 15273  You must be able to: P1 confirm the technical ...
# 15274  You must be able to: 1. write in a style that ...
# 15275  You must be able to: P1 write formal and infor...
# 15276  You must be able to: P1 define the profile and...
# 15277  You must be able to: P1 ensure that your work ...
#
#                              Knowledge and understanding  \
# 0                                                    NaN
# 1      You need to know and 1. relevant health and sa...
# 2      You need to know and K1 the relevant health an...
# 3      You need to know and K1 how to access and inte...
# 4      You need to know and K1 your own level of comp...
# ...                                                  ...
# 15273  You need to know and K1 communication and pres...
# 15274  You need to know and 1. the conventions and re...
# 15275                                                NaN
# 15276  You need to know and K1 what your organisation...
# 15277                                                NaN
#
#                                   Additional Information  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Glossary Health and safety legislation, regula...
# 3      Glossary Key terms Examples Regulations and gu...
# 4      External Links This standard links with the fo...
# ...                                                  ...
# 15273                                                NaN
# 15274                                                NaN
# 15275  Scope/range You can do this: 1. writing clearl...
# 15276                                                NaN
# 15277  Scope/range 1 write technical reports for both...
#
#                                             Developed by  \
# 0                                                    NaN
# 1      NSAFD Version Number 2 Date Approved March 201...
# 2      People 1st Version number 1 Date approved Apri...
# 3      Cogent Version number 1 Date approved January ...
# 4      Skills for Health Version number 1 Date approv...
# ...                                                  ...
# 15273  Cogent Version number 1 Date approved October ...
# 15274  Creative Skillset Version Number 2 Date Approv...
# 15275  Skills CFA Version number 1 Date approved Janu...
# 15276  Creative and Cultural Skills Version number 1 ...
# 15277  SEMTA Version number 1 Date approved January 2...
#
#                                                Key words
# 0                                                    NaN
# 1      Timber; wood; abrasive; wheel; saw; cut; sawmi...
# 2      Responsibility; control; handover PPLRETRS17 A...
# 3      accept, verify, store, materials, process, ope...
# 4      calibrate, evaluate, procurement SFHCHS202 Acc...
# ...                                                  ...
# 15273  write, technical content, safety case, data, p...
# 15274  Radio, Audio, Multiplatform, Content, Style, A...
# 15275  literacy; language; work; understand; communic...
# 15276  design, brie, designer, business, objectives, ...
# 15277  laboratory; workplace; reports; writing; techn...
#
# [15278 rows x 7 columns]

# %%
df2
# Out:
#                                                Filename  \
# 0     Access_information_with_and_for_young_people_f...
# 1     Access_overhead_line_equipment_construction_si...
# 2     Access_trees_by_climbing_to_carry_out_arboricu...
# 3     Access_trees_by_climbing_to_carry_out_treework...
# 4     Acquire,_store_and_issue_resources_to_provide_...
# ...                                                 ...
# 7355      _Form_rolled_products_in_food_operations_.pdf
# 7356  _Improve_Environmental_Performance_in_Support_...
# 7357  _Pin,_block_and_shape_dough_in_bakery_operatio...
# 7358  _Plan_the_transportation_of_goods_in_the_suppl...
# 7359  _Promote_Efficient_Transport_Usage_within_Sust...
#
#                                                Overview  \
# 0     This standard is about supporting young people...
# 1     This standard identifies the competences you n...
# 2     This standard is about accessing trees by clim...
# 3     This standard covers all the activities that m...
# 4     As this standard applies across a range of wor...
# ...                                                 ...
# 7355  This standard is about the skills and knowledg...
# 7356  This standard describes the skill and knowledg...
# 7357  This standard covers the skills and knowledge ...
# 7358  This standard is about planning the transporta...
# 7359  This standard is about developing policies and...
#
#                                    Performance criteria  \
# 0     You must be able to: 1. establish and assess t...
# 1     You must be able to: P1 maintain safe working ...
# 2     You must be able to: 1. perform a hazard evalu...
# 3     You must be able to: 1. obtain the relevant in...
# 4     You must be able to: Monitor and acquire resou...
# ...                                                 ...
# 7355  You must be able to: 1. operate to the legal o...
# 7356  You must be able to: P1 confirm that the resou...
# 7357  You must be able to: 1. check the available do...
# 7358  You must be able to: 1. identify the current t...
# 7359  You must be able to: P1 establish current leve...
#
#                             Knowledge and understanding  \
# 0     You need to know and understand: 1. why it is ...
# 1     You need to know and understand: K1 the releva...
# 2     You need to know and understand: 1. how to ide...
# 3     You need to know and understand: 1. how to ide...
# 4     You need to know and understand: Health and Sa...
# ...                                                 ...
# 7355  You need to know and understand: 1. the potent...
# 7356  You need to know and understand: K1 the reason...
# 7357  You need to know and understand: 1. the standa...
# 7358  You need to know and understand: 1. your organ...
# 7359  You need to know and understand: K1 the impact...
#
#                                  Additional Information  \
# 0                                                   NaN
# 1     performance criteria 1. Types of site access r...
# 2                                                   NaN
# 3     equired to carry out work activities could inc...
# 4     ions are provided to explain how key words and...
# ...                                                 ...
# 7355                                                NaN
# 7356  wner/Manager; Environmental Manager; Environme...
# 7357                                                NaN
# 7358  permanent, temporary, agency staff, external •...
# 7359  an be social, economic and environmental Effic...
#
#                                            Developed by  \
# 0     CLD Standards Council Scotland Version Number ...
# 1     NSAR Version Number 2 Date Approved 30 Apr 202...
# 2     Lantra Version Number 1 Date Approved 28 Feb 2...
# 3     Lantra Version Number 2 Date Approved 30 Apr 2...
# 4     Skills for Justice Version Number 3 Date Appro...
# ...                                                 ...
# 7355  Improve Version Number 4 Date Approved 30 Mar ...
# 7356  Cogent Version Number 2 Date Approved 30 Mar 2...
# 7357  Improve Version Number 4 Date Approved 30 Mar ...
# 7358  Lantra Version Number 2 Date Approved 30 Mar 2...
# 7359  Cogent Version Number 2 Date Approved 30 Mar 2...
#
#                                               Key words
# 0     Youth; young people; information; decisions; s...
# 1     Rail engineering; safety; access; overhead lin...
# 2     Tree; climb LANTw77L Access trees by climbing ...
# 3     trees; climb LANTw23 Access trees by climbing ...
# 4     Obtain, purchase, stock, monitor, supply, orde...
# ...                                                 ...
# 7355  Food; drink; manufacturing; operations; rolled...
# 7356  environmental; performance; sustainable; busin...
# 7357  Dough; Pin; Block; Shape; Craft; Bakery; Baker...
# 7358  plan; transportation; goods; supply chain SFLS...
# 7359  purchasing, supply, production, storage, packa...
#
# [7360 rows x 7 columns]

# %%
# Merge the two DataFrames row-wise
merged_df = pd.concat([df1, df2], ignore_index=True)

# Save to a new Excel file
merged_df.to_excel("parsed_nos(pdf+web).xlsx", index=False)

print("Merge completed successfully!")
# Out:
# Merge completed successfully!

# %%
merged_df.columns = merged_df.columns.str.lower().str.replace(" ", "_")

# Rename specific column "file_name" to "nos_title"
merged_df.rename(columns={"filename": "nos_title"}, inplace=True)

# Save the updated DataFrame to a new Excel file
merged_df.to_excel("C:\\Users\\amith\\Kenpath\\parsed_nos(pdf+web).xlsx", index=False)

print("Column names updated successfully!")
# Out:
# Column names updated successfully!

# %%
import pandas as pd
import re

def standardize_title(title, remove_pdf=True):
    """
    Standardize title format by:
    1. Removing special characters
    2. Replacing spaces with underscores
    3. Optionally removing .pdf extension
    """
    # Remove special characters and replace spaces with underscores
    standardized = re.sub(r'[\\/*?:"<>|]', "", title).replace(" ", "_")
    
    # Remove .pdf extension if present and requested
    if remove_pdf and standardized.endswith('.pdf'):
        standardized = standardized[:-4]
        
    return standardized

def convert_to_space_format(title):
    """
    Convert underscore title to space format and remove .pdf
    """
    # Remove .pdf if present
    if title.endswith('.pdf'):
        title = title[:-4]
    # Replace underscores with spaces
    return title.replace("_", " ")

def merge_excel_files(file1_path, file2_path, output_path):
    """
    Merge two Excel files based on nos_title column with format matching
    """
    # Read both Excel files
    df1 = pd.read_excel(file1_path)
    df2 = pd.read_excel(file2_path)
    
    # Create standardized title columns for matching
    df1['standardized_title'] = df1['nos_title'].apply(lambda x: standardize_title(x, remove_pdf=False))
    df2['standardized_title'] = df2['nos_title'].apply(lambda x: standardize_title(x, remove_pdf=True))
    
    # Store the space-formatted titles from df1
    title_mapping = dict(zip(df1['standardized_title'], df1['nos_title']))
    
    # For any titles only in df2, convert them to space format
    df2_only_titles = set(df2['standardized_title']) - set(df1['standardized_title'])
    for title in df2_only_titles:
        original_title = df2.loc[df2['standardized_title'] == title, 'nos_title'].iloc[0]
        title_mapping[title] = convert_to_space_format(original_title)
    
    # Merge dataframes on standardized title
    merged_df = pd.merge(
        df1, 
        df2,
        left_on='standardized_title',
        right_on='standardized_title',
        how='outer',
        suffixes=('_1', '_2')
    )
    
    # Create single nos_title column using the mapping
    merged_df['nos_title'] = merged_df['standardized_title'].map(title_mapping)
    
    # Drop temporary and duplicate columns
    columns_to_drop = ['standardized_title', 'nos_title_1', 'nos_title_2']
    merged_df = merged_df.drop([col for col in columns_to_drop if col in merged_df.columns], axis=1)
    
    # Save to new Excel file
    merged_df.to_excel(output_path, index=False)
    
    # Print merge statistics
    print(f"File 1 rows: {len(df1)}")
    print(f"File 2 rows: {len(df2)}")
    print(f"Merged rows: {len(merged_df)}")
    
    return merged_df

# Usage example:
file1_path = "C:\\Users\\amith\\Kenpath\\latest_nos_data.xlsx"  # File with "Abrasive wheel operations in the wood industry" format
file2_path = "C:\\Users\\amith\\Kenpath\\parsed_nos(pdf+web).xlsx" # File with "Abrasive_wheel_operations_in_the_wood_industry.pdf" format
output_path = "C:\\Users\\amith\\Kenpath\\complete_nos.xlsx"
merged_df = merge_excel_files(file1_path, file2_path, output_path)
# Out:
# File 1 rows: 23976
# File 2 rows: 22638
# Merged rows: 24660

# %%
merged_df
# Out:
#               urn                                             suites  \
# 0       ESKIDPS1L                                       IT Users 6.2
# 1       ESKIDPS2L                                       IT Users 6.2
# 2       ESKIDPS3L                                       IT Users 6.2
# 3         PROSM09                                         Sawmilling
# 4      PPLRETRS17                                   Rail Engineering
# ...           ...                                                ...
# 24655    COSVR414    Accessing Operations and Rigging (Construction)
# 24656   IMILVBP18  Accident Repair - Joining, Maintenance and Rep...
# 24657     ASTBSC1                                Specialist Cleaning
# 24658    ASTH413L                                            Housing
# 24659    ASTH325L                                            Housing
#
#                                              occupations   soc developed_by_1  \
# 0      Application Support, ICT for Users, Informatio...  3132       e-skills
# 1      Application Support, ICT for Users, Informatio...  3132       e-skills
# 2      Application Support, ICT for Users, Informatio...  3132       e-skills
# 3                      Paper and Wood Machine Operatives  8131       NSAFD v2
# 4                       Transport Drivers and Operatives  8153      Enginuity
# ...                                                  ...   ...            ...
# 24655                   Scaffolders, Stagers and Riggers  8151           CITB
# 24656                                     Vehicle Trades  5232            IMI
# 24657                    Specialist Cleaning Occupations  9223   Asset Skills
# 24658  Health and Social Care, Health, Public Service...  1251   Asset Skills
# 24659  Health and Social Care, Health, Public Service...  1251   Asset Skills
#
#             approved_on                                           web_link  \
# 0      15/03/2015 00:00                                                NaN
# 1      15/03/2015 00:00                                                NaN
# 2      15/03/2015 00:00                                                NaN
# 3      01/04/2020 00:00                                                NaN
# 4      15/03/2015 00:00                                                NaN
# ...                 ...                                                ...
# 24655  08/05/2022 00:00  https://www.ukstandards.org.uk/en/nos-finder/C...
# 24656  15/03/2015 00:00                                                NaN
# 24657  15/03/2015 00:00                                                NaN
# 24658  15/01/2017 00:00                                                NaN
# 24659  15/01/2017 00:00                                                NaN
#
#                                                 pdf_link  \
# 0      https://files.ukstandards.org.uk/pdfs/ESKIDPS1...
# 1      https://files.ukstandards.org.uk/pdfs/ESKIDPS2...
# 2      https://files.ukstandards.org.uk/pdfs/ESKIDPS3...
# 3      https://files.ukstandards.org.uk/pdfs/PROSM09.pdf
# 4      https://files.ukstandards.org.uk/pdfs/PPLRETRS...
# ...                                                  ...
# 24655                                                NaN
# 24656  https://files.ukstandards.org.uk/pdfs/IMILVBP1...
# 24657  https://files.ukstandards.org.uk/pdfs/ASTBSC1.pdf
# 24658  https://files.ukstandards.org.uk/pdfs/ASTH413.pdf
# 24659  https://files.ukstandards.org.uk/pdfs/ASTH325.pdf
#
#                                                 overview  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      This standard covers the skills and knowledge ...
# 4      This unit is about accepting and returning res...
# ...                                                  ...
# 24655  "This standard is about preparing, installing,...
# 24656  This NOS is about the straightforward removal ...
# 24657  This standard is about cleaning biohazard scen...
# 24658  This standard is about enabling the availabili...
# 24659  This standard is about working directly with c...
#
#                                     performance_criteria  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      You must be able to: 1. carry out risk assessm...
# 4      You must be able to: P1 work safely at all tim...
# ...                                                  ...
# 24655  You must be able to: P1 interpret the given in...
# 24656  You must be able to: P1 use the appropriate pe...
# 24657  You must be able to: P1 assess the risks assoc...
# 24658  You must be able to: P1 develop and manage sys...
# 24659  You must be able to: P1 fully explore and ackn...
#
#                              knowledge_and_understanding  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      You need to know and 1. relevant health and sa...
# 4      You need to know and K1 the relevant health an...
# ...                                                  ...
# 24655  You need to know and understand: Performance C...
# 24656  You need to know and Legislative and organisat...
# 24657  You need to know and K1 how to assess risks at...
# 24658  You need to know and K1 the reasons for securi...
# 24659  You need to know and K1 how customer and situa...
#
#                                   additional_information  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      Glossary Health and safety legislation, regula...
# ...                                                  ...
# 24655  performance criteria Performance Criteria 1 1 ...
# 24656  Scope/range 1. Basic MET components includes: ...
# 24657                                                NaN
# 24658                                                NaN
# 24659                                                NaN
#
#                                           developed_by_2  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      NSAFD Version Number 2 Date Approved March 201...
# 4      People 1st Version number 1 Date approved Apri...
# ...                                                  ...
# 24655  CITB Version Number 4 Date Approved 08 May 202...
# 24656  IMI Ltd Version number 1 Date approved January...
# 24657  Asset Skills Version number 1.0 Date approved ...
# 24658  Asset Skills Version number 2 Date approved Ja...
# 24659  Asset Skills Version number 2 Date approved Ja...
#
#                                                key_words  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      Timber; wood; abrasive; wheel; saw; cut; sawmi...
# 4      Responsibility; control; handover PPLRETRS17 A...
# ...                                                  ...
# 24655  Chimneys; Ducting; Sheet-metal cladding; Rivet...
# 24656  Basic Motor Mechanical Electrical Trim MET Com...
# 24657  biohazard scene, crime scene, pathogens, body ...
# 24658  Availability; additional; homes; landlords AST...
# 24659  Customers; carers; families; additional needs;...
#
#                                                nos_title
# 0                2D Drawing and planning software LEGACY
# 1                2D Drawing and planning software LEGACY
# 2                2D Drawing and planning software LEGACY
# 3         Abrasive wheel operations in the wood industry
# 4      Accept, and return, responsibility for the con...
# ...                                                  ...
# 24655  install sheet metal cladding to chimneys and d...
# 24656  remove and fit basic motor Mechanical, Electri...
# 24657                work at and clean a biohazard scene
# 24658  work with the private sector to increase the a...
# 24659  work within appropriate boundaries with custom...
#
# [24660 rows x 15 columns]

# %%
merged_df.isnull().sum()
# Out:
# urn                                1
# suites                             1
# occupations                        1
# soc                              575
# developed_by_1                     1
# approved_on                       13
# web_link                       16539
# pdf_link                        8008
# overview                         661
# performance_criteria            3362
# knowledge_and_understanding     3337
# additional_information         12483
# developed_by_2                   656
# key_words                        690
# nos_title                          0
# dtype: int64
