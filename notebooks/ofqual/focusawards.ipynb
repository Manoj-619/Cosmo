# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse

BASE_URL = "https://focusawards.org.uk/qualifications/"

def get_absolute_links(page_url):
    """ Get all qualification links from the main page and filter out invalid links. """
    response = requests.get(page_url)
    if response.status_code != 200:
        print(f"Failed to fetch {page_url}")
        return []

    soup = BeautifulSoup(response.text, "html.parser")
    links = set()  # Use a set to remove duplicates

    for a in soup.find_all("a", href=True):
        abs_link = urljoin(BASE_URL, a["href"])
        parsed_link = urlparse(abs_link)

        # Ensure the link is from the same domain and is not a fragment/mailto link
        if parsed_link.netloc == urlparse(BASE_URL).netloc and not parsed_link.fragment and not parsed_link.scheme.startswith("mailto"):
            links.add(abs_link)

    print(f"Valid qualification links found: {len(links)}")
    return list(links)

def scrape_pdf_links(links):
    """ Visit each link and extract the PDF link. """
    pdf_links = []
    for link in links:
        response = requests.get(link)
        if response.status_code != 200:
            print(f"Failed to fetch {link}")
            continue

        soup = BeautifulSoup(response.text, "html.parser")
        pdf_tag = soup.select_one("#content > div > section > div.container-fluid > div > div > div.dddd > div > a")

        if pdf_tag and pdf_tag.get("href", "").endswith(".pdf"):
            pdf_links.append(urljoin(link, pdf_tag["href"]))

    return pdf_links

# Step 1: Get all valid qualification links
qualification_links = get_absolute_links(BASE_URL)

# Step 2: Scrape PDF links from each qualification page
pdf_links = scrape_pdf_links(qualification_links)

# Print the extracted PDF links
print(pdf_links)
# Out:
# Valid qualification links found: 282
# ['https://focusawards.org.uk/wp-content/uploads/2024/05/Focus-Awards-Level-2-Certificate-in-Supporting-Learning-in-Physical-Education-and-Learning-School-Sport-CYM.pdf', 'https://focusawards.org.uk/wp-content/uploads/2024/09/WS-Focus-Awards-Level-5-Diploma-in-Leading-and-Managing-an-Adult-Care-Service.pdf', 'https://focusawards.org.uk/wp-content/uploads/2025/02/WS-Focus-Awards-Level-3-Award-in-AI-in-Education-RQF.pdf', 'https://focusawards.org.uk/wp-content/uploads/2025/01/Focus20Awards20Level20320Diploma20in20Exercise20Referral2028RQF29_New_MR2028129-compressed.pdf', 'https://focusawards.org.uk/wp-content/uploads/2024/05/Focus-Award-Level-3-Award-in-Employment-Awareness-in-Active-Leisure-and-Learning-RQF.pdf', 'https://focusawards.org.uk/wp-content/uploads/2025/01/Focus-Awards-Level-4-Certificate-in-Leading-the-Internal-Quality-Cymraeg-compressed.pdf', 'https://focusawards.org.uk/wp-content/uploads/2025/01/Focus-Awards-Level-5-Certificate-in-Gut-Microbiome-and-Nutrition-WS.pdf', 'https://focusawards.org.uk/wp-content/uploads/2022/12/WS-Focus-Awards-Level-3-Award-in-Employment-Awareness-in-Active-Leisure-and-Learning-RQF.pdf', 'https://focusawards.org.uk/wp-content/uploads/2023/06/WEBSPEC-L3-Certificate-in-Designing-Body-and-Face-Art-RQF23.pdf', 'https://www.focusawards.org.uk/wp-content/uploads/2019/05/WS-Focus-Awards-Level-2-Certificate-in-Customer-Service-RQF.pdf', 'https://focusawards.org.uk/wp-content/uploads/2022/12/WS-Focus-Awards-Level-2-Diploma-in-Beauty-Therapy-RQF.pdf', 'https://qualitas.focusawards.org.uk/qfilex/hopfile1686849521WS%20-%20Focus%20Awards%20Level%203%20Certificate%20in%20Leisure%20Management%20(RQF)%20D22.pdf', 'https://focusawards.org.uk/wp-content/uploads/2023/03/WS-Focus-Awards-Level-2-Award-in-Instructing-Weight-Training-RQF.pdf', 'https://focusawards.org.uk/wp-content/uploads/2023/02/WS-Focus-Awards-Level-2-Award-in-Instructing-Kettlebell-Exercises-RQF.pdf', 'https://focusawards.org.uk/wp-content/uploads/2023/01/WS-Focus-Awards-Level-3-Diploma-in-Combined-Nail-Technology-Skills-RQF.pdf', 'https://focusawards.org.uk/wp-content/uploads/2024/07/WS24-Focus-Awards-Level-3-Diploma-in-Reflexology-RQF_New-2024-.pdf', 'https://focusawards.org.uk/wp-content/uploads/2023/04/WS-Focus-Awards-Level-2-Certificate-in-Coaching-Strength-and-Conditioning-for-Sport-RQF.pdf', 'https://focusawards.org.uk/wp-content/uploads/2023/03/WS-Focus-Awards-Level-2-Award-in-Instructing-Studio-Cycling-RQF.pdf', 'https://focusawards.org.uk/wp-content/uploads/2024/05/WS-Focus-Awards-Level-3-diploma-for-the-children-and-young-peoples-worksforce-RQF-2023.pdf', 'https://focusawards.org.uk/wp-content/uploads/2025/02/WS25-Focus-Awards-Level-2-Award-in-Front-of-Stage-Pit-Barrier-Operations-RQF_New-copy-1.pdf', 'https://focusawards.org.uk/wp-content/uploads/2024/06/WS-Focus-Awards-Level-4-Certificate-in-Skin-Needling-Treatments-RQF_New-copy.pdf', 'https://qualitas.focusawards.org.uk/qfilex/hopfile1686846997WS%20-%20Focus%20Awards%20Level%202%20Certificate%20in%20Coaching%20Weight%20Lifting%20(RQF)%20-%20J23.pdf', 'https://focusawards.org.uk/wp-content/uploads/2024/07/WELSHWS24-Focus-Awards-Level-3-Diploma-in-Specialist-Support-for-Teaching-and-Learning-in-Schools-en_gb-cy_gb-C-1.pdf', 'https://focusawards.org.uk/wp-content/uploads/2024/06/v1.2-WS-L4-Certificate-in-Micropigmentation-RQF-Qualification-D22.pdf', 'https://focusawards.org.uk/wp-content/uploads/2023/01/WS-Focus-Awards-Level-2-Certificate-in-Fitness-Instructing-Fitness-Pilates-RQF.pdf', 'https://www.focusawards.org.uk/wp-content/uploads/2019/11/WS-Focus-Awards-Entry-Level-Certificate-for-Introduction-to-Customer-Service-Entry-3-RQF.pdf', 'https://qualitas.focusawards.org.uk/qfilex/hopfile1686844877WS%20-%20%20%20Focus%20Awards%20Level%202%20NVQ%20Certificate%20in%20Active%20Leisure,%20Learning%20and%20Well-Being%20Operational%20Services%20(RQF)%20%20.pdf', 'https://qualitas.focusawards.org.uk/qfilex/hopfile1686935024WS%20-%20Focus%20Awards%20Level%201%20Award%20in%20Employabilit ...

# %%
import os
import requests
from concurrent.futures import ThreadPoolExecutor

# Directory to save PDFs
SAVE_DIR = r"C:\Users\amith\Kenpath\OFQUAL\focusawards_pdfs"
os.makedirs(SAVE_DIR, exist_ok=True)

def download_pdf(pdf_url):
    """ Download a single PDF file. """
    pdf_name = os.path.join(SAVE_DIR, pdf_url.split("/")[-1])  # Extract filename
    try:
        response = requests.get(pdf_url, stream=True)
        if response.status_code == 200:
            with open(pdf_name, "wb") as pdf_file:
                for chunk in response.iter_content(chunk_size=1024):
                    pdf_file.write(chunk)
        else:
            print(f"Failed to download: {pdf_url}")
    except Exception as e:
        print(f"Error downloading {pdf_url}: {e}")

def download_pdfs_concurrently(pdf_links, max_threads=5):
    """ Download PDFs using multithreading. """
    with ThreadPoolExecutor(max_threads) as executor:
        executor.map(download_pdf, pdf_links)


# Download PDFs concurrently
download_pdfs_concurrently(pdf_links, max_threads=15)
# Out:
# Failed to download: https://qualitas.focusawards.org.uk/qfilex/hopfile1686849521WS%20-%20Focus%20Awards%20Level%203%20Certificate%20in%20Leisure%20Management%20(RQF)%20D22.pdf
# Failed to download: https://qualitas.focusawards.org.uk/qfilex/hopfile1686846997WS%20-%20Focus%20Awards%20Level%202%20Certificate%20in%20Coaching%20Weight%20Lifting%20(RQF)%20-%20J23.pdf
# Failed to download: https://qualitas.focusawards.org.uk/qfilex/hopfile1686935024WS%20-%20Focus%20Awards%20Level%201%20Award%20in%20Employability%20Skills%20(RQF)M23.pdf
# Failed to download: https://qualitas.focusawards.org.uk/qfilex/hopfile1686844877WS%20-%20%20%20Focus%20Awards%20Level%202%20NVQ%20Certificate%20in%20Active%20Leisure,%20Learning%20and%20Well-Being%20Operational%20Services%20(RQF)%20%20.pdf
# Failed to download: https://www.focusawards.org.uk/wp-content/uploads/2019/05/WS-Focus-Awards-Level-2-Certificate-in-Customer-Service-RQF.pdf
# Failed to download: https://qualitas.focusawards.org.uk/qfilex/hopfile1686857011WS%20-%20Level%203%20Diploma%20in%20Bridal%20Hair%20and%20Make-up%20(RQF)%20D22.pdf
# Failed to download: https://www.focusawards.org.uk/wp-content/uploads/2019/11/WS-Focus-Awards-Entry-Level-Certificate-for-Introduction-to-Customer-Service-Entry-3-RQF.pdf
# Failed to download: https://qualitas.focusawards.org.uk/qfilex/hopfile1686845409WS%20-%20Focus%20Awards%20Level%202%20Award%20in%20Employment%20Awareness%20in%20Active%20Leisure%20and%20Learning%20(RQF)%20D22.pdf
# Failed to download: https://qualitas.focusawards.org.uk/qfilex/hopfile1686165525WS%20-%20Focus%20awards%20level%202%20certificate%20in%20supporting%20teaching%20and%20learning%20in%20schools%20(RQF)2023%20.pdf
# Failed to download: https://qualitas.focusawards.org.uk/qfilex/hopfile1686163526WS%20-%20Focus%20Awards%20Level%203%20Award%20in%20Mathematics%20for%20Numeracy%20Teaching%20(RQF)2023%20.pdf
# Failed to download: https://qualitas.focusawards.org.uk/qfilex/hopfile1