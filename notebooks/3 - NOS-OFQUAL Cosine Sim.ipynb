# %%
import os
os.chdir('/Users/mumtaz/Documents/projects/zavmo/zavmo-api/zavmo')

# %%
import pandas as pd
from dotenv import load_dotenv
load_dotenv()
pd.set_option('display.max_columns',500)

# %%
from helpers.chat import get_batch_openai_embedding

# %% [markdown]
# ### Nos Prep

# %%
nos_df = pd.read_csv("../docs/rgcn/nos.csv")
print(nos_df.shape)
# Out:
# (14157, 8)

# %%
nos_texts = [f"{row['title']} {row['overview']} {row['performance_criteria']} {row['knowledge_understanding']} {row['keywords']} {row['relevant_roles']}" for idx, row in nos_df.iterrows()]

embeddings_nos = get_batch_openai_embedding(nos_texts)

# %% [markdown]
# ### Ofqual Prep

# %%
ofqual_df = pd.read_csv("../docs/rgcn/ofqual_units.csv").drop_duplicates(subset=['unit_id']).reset_index(drop=True)
print(f"Ofqual Units: {ofqual_df.unit_id.nunique()}")
print(f"Ofqual IDs: {ofqual_df.ofqual_id.nunique()}")
# Out:
# Ofqual Units: 14342
# Ofqual IDs: 2182

# %%
len(ofqual_df['unit_id'].unique())
# Out:
# 14343

# %%
ofqual_df.shape
# Out:
# (14343, 15)

# %%
ofqual_texts = [f"{row['sector_subject_area']} {row['overview']} {row['unit_title']} {row['unit_description']} {row['unit_learning_outcomes']} {row['qualification_level']}" for idx, row in ofqual_df.iterrows()]

embeddings_ofqual = get_batch_openai_embedding(ofqual_texts)

# %% [markdown]
# ### Get top-10 Ofqual Units with Cosine Sim >= t

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
from neomodel import (
    StructuredNode, 
    StringProperty, 
    FloatProperty,
    RelationshipTo,
    RelationshipFrom,
    ArrayProperty
)

class NOSNode(StructuredNode):
    nos_id   = StringProperty(unique_index=True, required=True)    
    industry = StringProperty()
    title = StringProperty()
    overview = StringProperty()
    performance_criteria = StringProperty()
    knowledge_understanding = StringProperty()
    keywords = StringProperty()
    relevant_roles = StringProperty()
    embedding = ArrayProperty(FloatProperty(), required=True)  # Add embedding vector
    
    ofqual_units = RelationshipTo('OFQUALUnit', 'MAPS_TO')

class OFQUALUnit(StructuredNode):
    ofqual_id = StringProperty(index=True)
    unit_id = StringProperty(unique_index=True, required=True)
    
    overview = StringProperty()
    unit_title = StringProperty()
    unit_description = StringProperty()
    unit_learning_outcomes = StringProperty()
    qualification_type = StringProperty()
    qualification_level = StringProperty()
    assessment_methods = StringProperty()
    sector_subject_area = StringProperty()
    awarding_organisation = StringProperty()
    total_credits = FloatProperty()
    guided_learning_hours = FloatProperty()
    total_qualification_time = FloatProperty()
    awarding_organization = StringProperty()
    
    
    embedding = ArrayProperty(FloatProperty(), required=True)  # Add embedding vector
    
    nos_items = RelationshipFrom('NOSNode', 'MAPS_TO')

# %%
# Configure neomodel
from neomodel import config
DATABASE_URL = f'bolt://{os.getenv("NEO4J_USERNAME")}:{os.getenv("NEO4J_PASSWORD")}@{os.getenv("NEO4J_URI")}'
# DATABASE_URL = "bolt://neo4j:secretgraph@localhost:7687"
config.DATABASE_URL = DATABASE_URL

# %%
DATABASE_URL
# Out:
# 'bolt://neo4j:zavmoadmin@51.20.45.38'

# %%
from neomodel import db
print(db.url)  # Should print "bolt://neo4j:password@localhost:7687"
# Out:
# None

# %% [markdown]
# # Create NOS nodes with embeddings

# %%
# Prepare the data for batch creation
nos_data = []
for idx, row in nos_df.iterrows():
    nos_data.append({
        'nos_id': row['nos_id'],
        'industry': row['industry'],
        'title': row['title'],
        'overview': row['overview'],
        'performance_criteria': row['performance_criteria'],
        'knowledge_understanding': row['knowledge_understanding'],
        'keywords': row['keywords'],
        'relevant_roles': row['relevant_roles'],
        'embedding': embeddings_nos[idx]
        })

# %%
import tqdm

# %%
BATCH_SIZE = 1000

# Process NOS nodes in batches
for i in tqdm.tqdm(range(0, len(nos_data), BATCH_SIZE)):
    batch = nos_data[i:i + BATCH_SIZE]
    with db.transaction:
        batch_nodes = NOSNode.create_or_update(*batch)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# 100%|██████████| 15/15 [01:52<00:00,  7.50s/it]

# %% [markdown]
# # Create OFQUAL nodes with embeddings

# %%
# Similarly for OFQUAL nodes
ofqual_data = []
for idx, row in ofqual_df.iterrows():
    ofqual_data.append({
        'ofqual_id': row['ofqual_id'],
        'unit_id': row['unit_id'],
        'overview': row['overview'],
        'unit_title': row['unit_title'],
        'unit_description': row['unit_description'],
        'unit_learning_outcomes': row['unit_learning_outcomes'],
        'qualification_type': row['qualification_type'],
        'qualification_level': row['qualification_level'],
        'assessment_methods': row['assessment_methods'],
        'sector_subject_area': row['sector_subject_area'],
        'awarding_organisation': row['awarding_organisation'],
        'total_credits': row['total_credits'],
        'guided_learning_hours': row['guided_learning_hours'],
        'total_qualification_time': row['total_qualification_time'],
        'awarding_organization': row['awarding_organization'],
        'embedding': embeddings_ofqual[idx]
    })

# %%
BATCH_SIZE = 1000

# Process OFQUAL nodes in batches
for i in tqdm.tqdm(range(0, len(ofqual_data), BATCH_SIZE)):
    batch = ofqual_data[i:i + BATCH_SIZE]
    with db.transaction:
        batch_nodes = OFQUALUnit.create_or_update(*batch)
# Out:
# 100%|██████████| 15/15 [01:55<00:00,  7.72s/it]

# %% [markdown]
# ## Connecting NOS to OFQUAL

# %%
# Convert all embeddings to numpy arrays at once
nos_embeddings_array = np.vstack(embeddings_nos)
ofqual_embeddings_array = np.vstack(embeddings_ofqual)

# Calculate all cosine similarities at once
print("Calculating similarities and creating relationships...")
all_similarities = cosine_similarity(nos_embeddings_array, ofqual_embeddings_array)

# Track relationship counts
relationship_count = 0

# %%
threshold = 0.0
top_k = 5

# %%
# Process similarities for each NOS document and create relationships directly
for nos_idx, similarities in enumerate(all_similarities):
    # Get indices where similarity is above threshold

    above_threshold_indices = np.where(similarities >= threshold)[0] 

    
    if len(above_threshold_indices) > 0:
        # Get the similarity scores for these indices
        scores = similarities[above_threshold_indices]
        
        # If we have more matches than top_k, find the indices of top_k highest scores
        if len(above_threshold_indices) > top_k:
            # Get indices of top_k highest scores
            top_indices = np.argsort(scores)[-top_k:]
            # Get the corresponding ofqual indices and scores
            selected_ofqual_indices = above_threshold_indices[top_indices]
        else:
            # Use all matches
            selected_ofqual_indices = above_threshold_indices
        
        # Get the NOS node
        nos_row  = nos_df.iloc[nos_idx]

        nos_node = NOSNode.nodes.get(nos_id=nos_row['nos_id'])
        print(nos_node)
        # Check if the NOS node already has connections to OFQUAL units
        existing_connections = len(list(nos_node.ofqual_units))

        if existing_connections > 0:
            print(f"Existing connections: {existing_connections}")
            continue
        else:
            print(f"Creating new connections for NOS {nos_row['nos_id']}...")

        # Create relationships directly
        for ofqual_idx in selected_ofqual_indices:
            ofqual_row = ofqual_df.iloc[ofqual_idx]
            ofqual_node = OFQUALUnit.nodes.get(unit_id=ofqual_row['unit_id'])
            
            # Connect the nodes
            nos_node.ofqual_units.connect(ofqual_node)
            relationship_count += 1
            
            # Print progress every 1000 relationships
            if relationship_count % 1000 == 0:
                print(f"Created {relationship_count} relationships so far...")
# Out:
# {'nos_id': 'INSML013', 'industry': 'Management and Leadership', 'title': 'Ensure compliance with legal, regulatory, ethical and social requirements', 'overview': 'This standard focuses on ensuring that organizations comply with legal, regulatory, ethical, and social requirements. It encompasses monitoring compliance, developing supporting policies, and rectifying breaches while encouraging a culture of ethical governance.', 'performance_criteria': '- Monitor legal, regulatory, ethical, and social requirements and their impact on the organization.  \n- Evaluate consequences of non-compliance with these requirements.  \n- Develop policies to ensure compliance.  \n- Ensure colleagues understand and apply organizational policies and procedures.  \n- Monitor policy implementation and provide necessary support.  \n- Facilitate reporting of non-compliance concerns.  \n- Identify risks, hazards, and ethical issues; take corrective action.  \n- Encourage knowledge sharing while maintaining confidentiality.  \n- Adjust policies to prevent future non-compliance.  \n- Report compliance failures to stakeholders.  \n- Supply information to support compliance initiatives.', 'knowledge_understanding': "- Importance of an ethical and value-based governance approach.  \n- Legal frameworks governing organizations.  \n- Current and evolving social attitudes toward leadership practices.  \n- Comparison with how other organizations address social concerns.  \n- Identification of potential risks and ethical concerns.  \n- Specific legal and organizational policies relevant to the role.  \n- Understanding the organization's culture and supporting policies.  \n- Procedures for maintaining compliance and reporting issues.", 'keywords': 'Management, leadership, legal, regulatory, ethical, social, compliance.', 'relevant_roles': 'Managers, Senior Officials, leaders within Management and Leadership roles.', 'embedding': [0.02574865333735943, 0.03623553737998009, 0.04984617978334427, 0.022870337590575218, 0.005706428084522486, 0.029809532687067986, 0.02295958809554577, -0.02232368104159832, -0.004334207624197006, 0.051318805664777756, 0.05542431026697159, -0.039046917110681534, -0.005268544889986515, -0.017124861478805542, -0.005059364717453718, -0.019579239189624786, -0.0051346695981919765, 0.00730177341029048, 0.0604669414460659, 0.041345108300447464, 0.05662918463349342, 0.05488881096243858, -0.0006759997340850532, 0.09210609644651413, -0.020482897758483887, -0.02150927297770977, 0.008473181165754795, 0.07349745184183121, -0.004610325209796429, -0.01569686084985733, 0.07434532791376114, -0.008975212462246418, -0.03445053845643997, -0.023472774773836136, -0.004939435049891472, 0.008328150026500225, 0.00213642418384552, 0.006983819883316755, -0.003932582214474678, 0.059574440121650696, 0.013800296001136303, -0.025994090363383293, 0.010369745083153248, 0.007664352189749479, -0.015708016231656075, -0.04685629904270172, -0.03445053845643997, -0.0441787987947464, -0.00038802874041721225, 0.026172591373324394, -0.02572634071111679, -0.040675729513168335, 0.04096579551696777, -0.00023637330741621554, 0.007206945214420557, 0.005527928005903959, 0.00044032372534275055, 0.007748024072498083, -0.05006930232048035, 0.04011791944503784, 0.019177613779902458, -0.010152198374271393, -0.030947471037507057, 0.018463613465428352, 0.026484966278076172, 0.03197384625673294, -0.0003737347724381834, -0.04020716995000839, 0.004724677186459303, -0.011239933781325817, 0.07318507879972458, 0.03877916559576988, 0.01319785788655281, -0.005455411970615387, -0.027511341497302055, -0.006476209964603186, 0.03110365942120552, 0.03735116496682167, -0.00789305567741394, -0.03382578492164612, -0.03199616074562073, -0.01787233166396618, -0.0267080906778574, 0.048150427639484406, 0.0046912082470953465, 0.0049645365215837955, -0.05984218791127205, 0.018842926248908043, -0.06055619195103645, 0.0026691355742514133, -0.025570152327418327, 0.02697584219276905, -0.049801554530858994, 0.02094030380 ...
# Existing connections: 5

# %%
# Create vector indexes
from neomodel import db

print("Creating vector indexes...")
# Create vector index for NOS nodes
db.cypher_query("""
CREATE VECTOR INDEX nos_vector_index IF NOT EXISTS
FOR (n:NOSNode)
ON (n.embedding)
OPTIONS {
    indexConfig: {
        `vector.dimensions`: 1536,
        `vector.similarity_function`: 'cosine'
    }
}
""")

# Create vector index for OFQUAL nodes
# db.cypher_query("""
# CREATE VECTOR INDEX ofqual_vector_index IF NOT EXISTS
# FOR (n:OFQUALUnit)
# ON (n.embedding)
# OPTIONS {
#     indexConfig: {
#         `vector.dimensions`: 1536,
#         `vector.similarity_function`: 'cosine'
#     }
# }
# """)
# Out:
# Creating vector indexes...
# ([], [])

# %% [markdown]
# #### Number of documents ingested in nos_vector_index

# %%
db.cypher_query("MATCH (n:NOSNode) WHERE n.embedding IS NOT NULL RETURN COUNT(n) AS indexed_documents;")
# Out:
# ([[14157]], ['indexed_documents'])

# %% [markdown]
# ## Retrieval

# %%
from typing import List
from openai import OpenAI
import ast


def get_embedding(text: str, model: str = "text-embedding-3-small") -> List[float]:
    """
    Get the embedding of a text using OpenAI's API.
    """
    client = OpenAI(api_key=os.environ['OPENAI_API_KEY'])
    response = client.embeddings.create(
        input=text,
        model=model
    )
    embedding = response.data[0].embedding
    return embedding

def retrieve_ofquals_from_neo4j(nos_id: str) -> List[str]:
    """Get the ofquals mapped to a nos_id"""
    query = """
    MATCH (n:NOSNode {nos_id: $nos_id})-[:MAPS_TO]->(o:OFQUALUnit)
    RETURN o.unit_id AS unit_id, o.unit_title AS unit_title, 
    o.overview AS overview, 
    o.level AS level, 
    o.qualification_type AS qualification_type, 
    o.qualification_level AS qualification_level, 
    o.awarding_organisation AS awarding_organisation, 
    o.total_credits AS total_credits, 
    o.guided_learning_hours AS guided_learning_hours, 
    o.total_qualification_time AS total_qualification_time, 
    o.unit_learning_outcomes AS learning_outcomes, 
    o.assessment_methods AS assessment_methods,
    o.markscheme AS marksscheme
    """
    
    # Execute the query
    results, _ = db.cypher_query(query, {'nos_id': nos_id})
    
    connected_ofqual_units = [{'unit_id': row[0], 'unit_title': row[1], 'overview': row[2], 'level': row[3], 
                        'qualification_type': row[4], 'qualification_level': row[5], 'awarding_organisation': row[6], 
                        'total_credits': row[7], 'guided_learning_hours': row[8], 'total_qualification_time': row[9], 
                        'learning_outcomes': row[10], 'assessment_methods': row[11], 'marksscheme': ast.literal_eval(row[12])} for row in results]
    
    ## If json item is a string, convert it to a json object
    [res.update({'marksscheme': [json.loads(i) for i in ast.literal_eval(res['marksscheme'])]}) for res in connected_ofqual_units]

    return connected_ofqual_units

def retrieve_nos_from_neo4j(query,index_name='nos_vector_index', top_k=5):
    """Retrieve NOS from Neo4j"""
    query_embedding = get_embedding(query)
    cypher_query = f"""
        CALL db.index.vector.queryNodes('{index_name}', $top_k, $query_embedding) 
            YIELD node, score
            RETURN 
                node.nos_id AS nos_id, 
                node.title AS title, 
                node.performance_criteria AS performance_criteria,
                node.knowledge_understanding AS knowledge_understanding,
                score
            ORDER BY score DESC
        """

    result, columns = db.cypher_query(cypher_query, {"query_embedding": query_embedding, "top_k": top_k})
        
    formatted_results = [dict(zip(columns, row)) for row in result]
        
    return formatted_results[:top_k]

# %%
query_text = """The Ethics & Compliance function provides assurance that Centrica operates in a manner consistent with its legal and regulatory obligations. 
The Energy Compliance team is responsible for establishing and maintaining a robust compliance framework for energy and ensuring the governance structure within which the framework sits is effective."""

query_text = "Ethics & Compliance professional in the energy sector, with a focus on establishing and maintaining compliance frameworks, regulatory compliance, and governance structures."

# query_embedding = get_batch_openai_embedding([query_text])[0]

# %%
results = retrieve_nos_from_neo4j(query_text, index_name='nos_vector_index', top_k=10)

# %%
nos_results = [res['nos_id'] for res in results]
nos_results
# Out:
# ['CFASAL021',
#  'CCSAPLE12',
#  'ASTNDEA1',
#  'CFAS7.7',
#  'ASTACEA1',
#  'ASTH401',
#  'CFAMAR10',
#  'ASTFM324',
#  'CLD YW03',
#  'CFAPSU023']

# %%
ofqual_results = retrieve_ofquals_from_neo4j('ASTFM405')
# Out:
# Received notification from DBMS server: {severity: WARNING} {code: Neo.ClientNotification.Statement.UnknownPropertyKeyWarning} {category: UNRECOGNIZED} {title: The provided property key is not in the database} {description: One of the property names in your query is not available in the database, make sure you didn't misspell it or that the label is available when you run this statement in your application (the missing property name is: level)} {position: line: 5, column: 7, offset: 165} for query: '\n    MATCH (n:NOSNode {nos_id: $nos_id})-[:MAPS_TO]->(o:OFQUALUnit)\n    RETURN o.unit_id AS unit_id, o.unit_title AS unit_title, \n    o.overview AS overview, \n    o.level AS level, \n    o.qualification_type AS qualification_type, \n    o.qualification_level AS qualification_level, \n    o.awarding_organisation AS awarding_organisation, \n    o.total_credits AS total_credits, \n    o.guided_learning_hours AS guided_learning_hours, \n    o.total_qualification_time AS total_qualification_time, \n    o.unit_learning_outcomes AS learning_outcomes, \n    o.assessment_methods AS assessment_methods,\n    o.markscheme AS marksscheme\n    '

# %%
ofqual_results
# Out:
# [{'unit_id': 'H/618/8072',
#   'unit_title': 'Estimate and Agree Costs with Clients',
#   'overview': 'ETCAL Level 3 Diploma in Facilities Management, focusing on establishing a robust framework of assessment principles specific to the facilities management sector.',
#   'level': None,
#   'qualification_type': 'Vocationally-Related Qualification',
#   'qualification_level': 'Level 3',
#   'awarding_organisation': '/organisations/RN5135',
#   'total_credits': 170.0,
#   'guided_learning_hours': 960.0,
#   'total_qualification_time': 1700.0,
#   'learning_outcomes': '1. Understand how to identify and agree the work to be estimated with relevant others.\r\n  - Explain the procedures for identifying and agreeing the work to be estimated with clients\r\n  - Explain how to identify the required resources from technical and legislative data.',
#   'assessment_methods': 'Aural Examination, Coursework, E-assessment, Multiple Choice Examination, Oral Examination, Portfolio of Evidence, Practical Demonstration/Assignment, Practical Examination, Written Examination',
#   'marksscheme': '["{\\"bloom_taxonomy_level\\":\\"Remember\\",\\"criteria\\":\\"Recall the procedures for identifying and agreeing the work to be estimated with clients.\\",\\"expectations\\":\\"Learners must accurately list the steps involved in the estimation process, demonstrating knowledge of key procedures and terminologies without providing detailed explanations.\\",\\"task\\":\\"List the steps involved in identifying and agreeing costs with clients in facility management.\\",\\"benchmarking_responses\\":[{\\"grade\\":\\"fail\\",\\"example\\":\\"The steps are not clear.\\"},{\\"grade\\":\\"pass\\",\\"example\\":\\"1. Meet with the client 2. Discuss costs 3. Finalize the agreement.\\"},{\\"grade\\":\\"merit\\",\\"example\\":\\"1. Meet with the client to understand their needs 2. Discuss the scope of work 3. Identify resources needed 4. Agree on the costs based on discussions.\\"},{\\"grade\\":\\"distinction\\",\\"example\\":\\"1. Schedule an initial meeting with the client to discuss their requirements. 2. Outline the scope of work efficiently to ensure all parties have the same understanding. 3. Conduct a thorough analysis of required resources based on technical and legislative guidelines. 4. Finalize and document the cost agreement, ensuring all stakeholders approve the terms.\\"}]}", "{\\"bloom_taxonomy_level\\":\\"Understand\\",\\"criteria\\":\\"Explain the procedures for identifying and agreeing the work to be estimated with clients.\\",\\"expectations\\":\\"Learners must demonstrate a clear and comprehensive understanding of the procedures involved, providing definitions and contextual insights.\\",\\"task\\":\\"Explain the procedures for estimating costs with clients in the facilities management context.\\",\\"benchmarking_responses\\":[{\\"grade\\":\\"fail\\",\\"example\\":\\"It involves talking to the client.\\"},{\\"grade\\":\\"pass\\",\\"example\\":\\"Estimating costs involves speaking with the client and discussing what they need.\\"},{\\"grade\\":\\"merit\\",\\"example\\":\\"To correctly estimate costs, one must first meet with the client to discuss their requirements and review the relevant technical data before agreeing on a budget.\\"},{\\"grade\\":\\"distinction\\",\\"example\\":\\"The procedure involves several stages: initiating client communication to establish requirements, reviewing technical resources to determine feasibility, discussing the details of each phase, and finally drafting a mutual cost agreement while adhering to all legislative guidelines.\\"}]}", "{\\"bloom_taxonomy_level\\":\\"Apply\\",\\"criteria\\":\\"Demonstrate the process of identifying the required resources from technical and legislative data.\\",\\"expectations\\":\\"Learners should successfully apply their understanding by showing how they would gather data and identify resources during an estimation task.\\",\\"task\\":\\"Provide a detailed example of how you would gather relevant resources from technical and legislative data for a facilities management project.\\",\\"benchmarking_responses\\":[{\\"grade\\":\\"fail\\",\\"example\\":\\"You need to look at data but no specifics are provided.\\"},{\\"grade\\":\\"pass\\",\\"example\\":\\"To gather resources, you should look at some technical data.\\"},{\\"grade\\":\\"merit\\",\\"example\\":\\"I will look at industry standards and regulations to gather the necessary legislative data and create a list of required materials for the project.\\"},{\\"grade\\":\\"distinction\\",\\"example\\":\\"In identifying required resources, I will first consult technical manuals and industry regulations, cross-referencing client needs with applicable laws to ensure compliance, then compile a comprehensive inventory that includes materials, labor, and tools needed for the project.\\"}]}", "{\\"bloom_taxonomy_level\\":\\"Analyze\\",\\"criteria\\":\\"Analyze the implications of not accurately estimating costs with clients.\\",\\"expectations\\":\\"Learners must critically assess the potential out ...
#  {'unit_id': 'J/651/2600',
#   'unit_title': 'Business Planning and Performance Monitoring',
#   'overview': "The Level 5 Diploma in Executive Housing and Property Management is designed to recognize learners' achievements and develop their understanding of housing and property management in various sectors.",
#   'level': None,
#   'qualification_type': 'Occupational Qualification',
#   'qualification_level': 'Level 5',
#   'awarding_organisation': '/organisations/RN5204',
#   'total_credits': 39.0,
#   'guided_learning_hours': 89.0,
#   'total_qualification_time': 385.0,
#   'learning_outcomes': '1. Undertake data analysis, interrogation, interpretation and dissemination of information.\r\n  - Collect, record, analyse and store information that is accurate, sufficient, relevant and in line with the organisation’s policies.\r\n  - Interrogate, present and share information using a variety of methods.\r\n  - Adopt the most appropriate way to communicate relevant information to stakeholders.\r\n  - Make effective use of IT equipment and software.\r\n2. Organise and plan work to ensure tasks are completed and deadlines are met.\r\n  - Outline the business planning process.\r\n  - Organise own time and priorities to meet business needs and to complete work on time.\r\n  - Embrace changing priorities and work patterns when requirements alter.\r\n3. Lead, motivate, manage, and develop individuals and teams.\r\n  - Demonstrate leadership and management skills to ensure business objectives are met.\r\n  - Evaluate own leadership and management skills identifying areas for personal development.\r\n4. Use a problem solving and flexible approach in day-to-day duties.\r\n  - Take ownership for the investigation and analysis of problems to achieve solutions in line with customer standards.\r\n  - Escalate problems to relevant people and follow through to ensure action has been taken.',
#   'assessment_methods': 'Multiple Choice Examination, Portfolio of Evidence',
#   'marksscheme': '["{\\"bloom_taxonomy_level\\":\\"Remember\\",\\"criteria\\":\\"Recall key concepts related to business planning and performance monitoring.\\",\\"expectations\\":\\"Learners must list and describe the foundational elements of business planning and performance monitoring.\\",\\"task\\":\\"List and briefly describe the main steps in the business planning process as outlined in the unit.\\",\\"benchmarking_responses\\":[{\\"grade\\":\\"fail\\",\\"example\\":\\"The business planning process includes some steps.\\"},{\\"grade\\":\\"pass\\",\\"example\\":\\"The business planning process involves steps like goal setting, researching, and writing a plan.\\"},{\\"grade\\":\\"merit\\",\\"example\\":\\"The business planning process includes key steps such as goal setting, market research, strategy development, and financial forecasting.\\"},{\\"grade\\":\\"distinction\\",\\"example\\":\\"The business planning process involves specific steps: setting clear objectives, conducting thorough market research, developing tailored strategies, and making accurate financial projections, which are crucial for effective performance monitoring.\\"}]}", "{\\"bloom_taxonomy_level\\":\\"Understand\\",\\"criteria\\":\\"Explain the significance of accurate data collection and analysis in business performance monitoring.\\",\\"expectations\\":\\"Learners should outline why accurate data is crucial, providing context within the framework of organizational policies.\\",\\"task\\":\\"Explain the importance of accurate data collection and analysis in the context of business planning and performance monitoring.\\",\\"benchmarking_responses\\":[{\\"grade\\":\\"fail\\",\\"example\\":\\"Data collection is important for business plans.\\"},{\\"grade\\":\\"pass\\",\\"example\\":\\"Accurate data collection helps in making better decisions for business planning and monitoring performance.\\"},{\\"grade\\":\\"merit\\",\\"example\\":\\"Accurate data collection and analysis are vital as they inform decision-making, reflect organizational policies, and ensure alignment with business goals.\\"},{\\"grade\\":\\"distinction\\",\\"example\\":\\"Accurate data collection and analysis are critical as they directly influence decision-making quality, compliance with organizational policies, and ensure that performance monitoring mechanisms reflect genuine business needs, consequently driving better outcomes.\\"}]}", "{\\"bloom_taxonomy_level\\":\\"Apply\\",\\"criteria\\":\\"Demonstrate effective planning techniques to organize personal work.\\",\\"expectations\\":\\"Learners should showcase how they can prioritize tasks to meet deadlines effectively.\\",\\"task\\":\\"Apply effective time management techniques to organize a week\'s worth of tasks to meet specific business objectives.\\",\\"benchmarking_responses\\":[{\\"grade\\":\\"fail\\",\\"example\\":\\"I have tasks I need to do next week.\\"},{\\"grade\\":\\"pass\\",\\"example\\":\\"I will plan my week by writing down tasks and scheduling time for them.\\"},{\\"grade\\":\\"merit\\",\\"example\\":\\"I created a weekly plan that prioritizes tasks based on urgency and importance, ensuring all are scheduled to meet business objectives on time.\\"},{\\"grade\\":\\"distinction\\",\\"example\\":\\"I implemented a detailed weekly work plan, using tools like Gantt charts to prioritize tasks by deadlines and dependencies, demonstrating flexibility to adjust as business needs shift.\\"}]}", "{\\"bloom_taxonomy_level\\":\\"Analyze\\",\\"criteria\\":\\"Investigate leadership styles and their impact on team performance.\\",\\"expectations\\":\\"Learners are to analyze different leadership methods and their effectiveness in various scenarios.\\",\\"task\\":\\"Analyze the effects of different leadership styles on team performance and outcomes in a specific case study.\\",\\"benchmarking_responses\\":[{\\"grade\\":\\"fail\\",\\"example\\":\\"Some leaders are good and some are not.\\"},{\\"grade\\":\\"pass\\",\\"example\\":\\"A ...
#  {'unit_id': 'F/618/0223',
#   'unit_title': 'Planning, Controlling and Leading a Project',
#   'overview': 'The OTHM Level 7 Diploma in Project Management qualification is designed for senior managers responsible for projects, providing a comprehensive understanding of project, programme and portfolio management.',
#   'level': None,
#   'qualification_type': 'Vocationally-Related Qualification',
#   'qualification_level': 'Level 7',
#   'awarding_organisation': '/organisations/RN5284',
#   'total_credits': 120.0,
#   'guided_learning_hours': 480.0,
#   'total_qualification_time': 1200.0,
#   'learning_outcomes': '1. Understand the concepts and principles of project management in business.\r\n  - Examine the role of project management in achieving business objectives.\r\n  - Explain the application of key concepts and principles of project management in different business environments.\r\n  - Appraise business objectives to determine potential projects.\r\n2. Be able to design systems and plans for initiating and managing projects.\r\n  - Examine key leadership and management theories related to project management.\r\n  - Develop role and responsibilities of the project manager for a project.\r\n  - Create a detailed project plan with time, resources and costs estimates.\r\n3. Be able to evaluate the effectiveness of communication within a project management team.\r\n  - Explain the key contents of a project communication plan.\r\n  - Evaluate the benefits of a project communication plan to stakeholders.\r\n4. Be able to design monitoring and controlling mechanisms for a project.\r\n  - Evaluate risk factors that may impede completion of a project.\r\n  - Design systems to monitor and appraise the status of a project.\r\n5. Understand how to close and review the completion of a project.\r\n  - Explain the closing stages of a project.\r\n  - Assess the importance of project evaluation.',
#   'assessment_methods': 'Coursework',
#   'marksscheme': '["{\\"bloom_taxonomy_level\\":\\"Remember\\",\\"criteria\\":\\"Identify key concepts and principles of project management.\\",\\"expectations\\":\\"Learners must list fundamental concepts such as planning, executing, and evaluating projects that form the basis of project management.\\",\\"task\\":\\"List five key concepts of project management and briefly define each.\\",\\"benchmarking_responses\\":[{\\"grade\\":\\"fail\\",\\"example\\":\\"Project management is something about planning and stuff.\\"},{\\"grade\\":\\"pass\\",\\"example\\":\\"1. Planning: Creating a blueprint for the project. 2. Execution: Carrying out the project plan. 3. Monitoring: Keeping track of project progress. 4. Closing: Completing the project. 5. Evaluation: Assessing the project outcome.\\"},{\\"grade\\":\\"merit\\",\\"example\\":\\"1. Planning: Structuring the project with designated phases. 2. Execution: Implementing the plan using resources. 3. Monitoring: Continuously assessing performance against the plan. 4. Closing: Finalizing all activities and delivering project results. 5. Evaluation: Analyzing successes and failures.\\"},{\\"grade\\":\\"distinction\\",\\"example\\":\\"1. Planning: The process of defining project goals, scope, and procedures. 2. Execution: The stage where deliverables are developed and completed. 3. Monitoring: Systematic tracking of project milestones and performance. 4. Closing: Officially concluding project activities and evaluating outcomes. 5. Evaluation: A detailed review of project deliverables against objectives for future improvements.\\"}]}", "{\\"bloom_taxonomy_level\\":\\"Understand\\",\\"criteria\\":\\"Explain the application of project management principles in various business contexts.\\",\\"expectations\\":\\"Learners must describe how project management is implemented in different organizational settings to enhance business objectives.\\",\\"task\\":\\"Explain how project management can support business objectives in three different industries.\\",\\"benchmarking_responses\\":[{\\"grade\\":\\"fail\\",\\"example\\":\\"Project management helps businesses do better in general.\\"},{\\"grade\\":\\"pass\\",\\"example\\":\\"In healthcare, project management helps in implementing IT systems. In construction, it ensures projects are completed on time and in budget. In IT, project management is crucial for software development.\\"},{\\"grade\\":\\"merit\\",\\"example\\":\\"In healthcare, project management aids in project delivery for patient care improvement initiatives. In construction, it optimizes resource usage and timelines for building projects. In IT, it aligns technology projects with strategic goals, ensuring timely delivery.\\"},{\\"grade\\":\\"distinction\\",\\"example\\":\\"In healthcare, project management enhances quality by ensuring IT systems improve patient care efficaciously. In construction, it streamlines operations through critical path analysis to meet strict deadlines. In IT, it embeds agile practices ensuring that software projects adapt efficiently to rapid technological changes.\\"}]}", "{\\"bloom_taxonomy_level\\":\\"Apply\\",\\"criteria\\":\\"Demonstrate the ability to design a detailed project plan.\\",\\"expectations\\":\\"Learners must create a project plan that includes objectives, timelines, resource allocations, and cost estimates.\\",\\"task\\":\\"Develop a project plan for a hypothetical project in any industry, including resources and timelines.\\",\\"benchmarking_responses\\":[{\\"grade\\":\\"fail\\",\\"example\\":\\"I will finish my project in a week.\\"},{\\"grade\\":\\"pass\\",\\"example\\":\\"Project: Launch a new product. Goals include completing market research by week 2, development in weeks 3-5, and marketing by week 6.\\"},{\\"grade\\":\\"merit\\",\\"example\\":\\"Project: Launch an eco-friendly product. Timeline: Research Phase (2 weeks), Development Phase (3 weeks), Marketing Phase (2 weeks). Resources: Team of 5, budget $50,000.\\"},{\\"grade\\":\ ...
#  {'unit_id': 'Y/616/7946',
#   'unit_title': 'Monitoring Maintenance Activities',
#   'overview': 'This competence qualification is designed for individuals responsible for the planning, implementation and supervision of maintenance activities and personnel within mineral products operations, promoting safe and environmentally responsible working practices.',
#   'level': None,
#   'qualification_type': 'Occupational Qualification',
#   'qualification_level': 'Level 3',
#   'awarding_organisation': '/organisations/RN5195',
#   'total_credits': 102.0,
#   'guided_learning_hours': 302.0,
#   'total_qualification_time': 1020.0,
#   'learning_outcomes': '1. Monitor maintenance activities for quality and efficiency.\r\n  - Ability to assess the effectiveness of maintenance schedules.\r\n  - Documentation and reporting of maintenance outcomes.',
#   'assessment_methods': 'Portfolio of Evidence',
#   'marksscheme': '["{\\"bloom_taxonomy_level\\":\\"Remember\\",\\"criteria\\":\\"Identify key factors for effective maintenance monitoring.\\",\\"expectations\\":\\"Learners must list specific factors related to monitoring maintenance that contribute to quality and efficiency.\\",\\"task\\":\\"List five key factors that influence the effectiveness of maintenance activities in mineral products operations.\\",\\"benchmarking_responses\\":[{\\"grade\\":\\"fail\\",\\"example\\":\\"Four factors are important in maintenance but I can\'t remember them all.\\"},{\\"grade\\":\\"pass\\",\\"example\\":\\"1. Scheduling 2. Personnel 3. Tools 4. Reporting\\"},{\\"grade\\":\\"merit\\",\\"example\\":\\"1. Scheduling must be timely. 2. Qualified personnel. 3. Proper tools and equipment. 4. Thorough reporting.\\"},{\\"grade\\":\\"distinction\\",\\"example\\":\\"1. Accurate scheduling enhances efficiency. 2. Skilled personnel ensure quality standards. 3. Advanced tools improve maintenance processes. 4. Comprehensive reporting aids accountability.\\"}]}", "{\\"bloom_taxonomy_level\\":\\"Understand\\",\\"criteria\\":\\"Explain the importance of monitoring maintenance activities.\\",\\"expectations\\":\\"Learners must demonstrate an understanding of how monitoring impacts maintenance effectiveness and compliance.\\",\\"task\\":\\"Explain why monitoring maintenance activities is crucial for ensuring quality and compliance in operations.\\",\\"benchmarking_responses\\":[{\\"grade\\":\\"fail\\",\\"example\\":\\"Monitoring is important but I don\'t know how.\\"},{\\"grade\\":\\"pass\\",\\"example\\":\\"Monitoring helps in checking work done.\\"},{\\"grade\\":\\"merit\\",\\"example\\":\\"Monitoring ensures that maintenance tasks are done correctly, impacting quality.\\"},{\\"grade\\":\\"distinction\\",\\"example\\":\\"Monitoring maintenance activities ensures adherence to schedules, enhances operational efficiency, and minimizes environmental impact.\\"}]}", "{\\"bloom_taxonomy_level\\":\\"Apply\\",\\"criteria\\":\\"Implement a basic maintenance monitoring plan.\\",\\"expectations\\":\\"Learners must demonstrate the ability to create a simple plan for monitoring maintenance that covers essential elements.\\",\\"task\\":\\"Design a basic maintenance monitoring plan for a specific maintenance activity.\\",\\"benchmarking_responses\\":[{\\"grade\\":\\"fail\\",\\"example\\":\\"I think we need to check things but I can\'t make a plan.\\"},{\\"grade\\":\\"pass\\",\\"example\\":\\"1. Schedule maintenance every month. 2. Record the tasks done. 3. Review the reports.\\"},{\\"grade\\":\\"merit\\",\\"example\\":\\"1. Schedule monthly maintenance. 2. Maintain a checklist of completed tasks. 3. Prepare a report after each maintenance session.\\"},{\\"grade\\":\\"distinction\\",\\"example\\":\\"1. Monthly scheduled maintenance reviewing machinery efficiency. 2. Utilize a checklist for comprehensive task coverage. 3. Analyze reports weekly for operational insights.\\"}]}", "{\\"bloom_taxonomy_level\\":\\"Analyze\\",\\"criteria\\":\\"Analyze maintenance outcomes and compliance levels.\\",\\"expectations\\":\\"Learners must be able to examine and interpret maintenance reports to draw conclusions about efficiency.\\",\\"task\\":\\"Analyze a given maintenance report and assess its effectiveness and compliance.\\",\\"benchmarking_responses\\":[{\\"grade\\":\\"fail\\",\\"example\\":\\"I looked at the report but don\'t know what it means.\\"},{\\"grade\\":\\"pass\\",\\"example\\":\\"The report shows some things done but not all were effective.\\"},{\\"grade\\":\\"merit\\",\\"example\\":\\"The report indicates that 80% of scheduled tasks were completed, which is a good efficiency rate.\\"},{\\"grade\\":\\"distinction\\",\\"example\\":\\"The analysis of the report reveals a 95% compliance rate with scheduled tasks, highlighting areas for improvement and reaffirming effective practices.\\"}]}", "{\\"bloom_taxonomy_level\\":\\"Evaluate\\",\\"criteria\\":\\"Evaluate the effective ...
#  {'unit_id': 'A/601/7652',
#   'unit_title': 'Principles of project management',
#   'overview': 'This qualification is for learners who want to develop the knowledge and understanding required to work in a range of environments in a supervisory business administration role.',
#   'level': None,
#   'qualification_type': 'Occupational Qualification',
#   'qualification_level': 'Level 3',
#   'awarding_organisation': '/organisations/RN5325',
#   'total_credits': 17.0,
#   'guided_learning_hours': 136.0,
#   'total_qualification_time': 170.0,
#   'learning_outcomes': '1. Know how to prepare for and plan a project.\r\n  - Explain why it is important to agree the purpose and objectives of a project\r\n  - Describe how to identify and plan for project issues and risks',
#   'assessment_methods': 'Portfolio of Evidence',
#   'marksscheme': '["{\\"bloom_taxonomy_level\\":\\"Remember\\",\\"criteria\\":\\"Identify key components of project management and their importance in project preparation.\\",\\"expectations\\":\\"Learners must list and define terms related to project planning and monitoring, demonstrating basic recall of concepts.\\",\\"task\\":\\"List the key components involved in preparing for a project and explain their significance.\\",\\"benchmarking_responses\\":[{\\"grade\\":\\"fail\\",\\"example\\":\\"The project components are important.\\"},{\\"grade\\":\\"pass\\",\\"example\\":\\"Some components of project management are purpose, objectives, and risks.\\"},{\\"grade\\":\\"merit\\",\\"example\\":\\"The key components include purpose, objectives, issues, and risks, which help in defining the direction of the project.\\"},{\\"grade\\":\\"distinction\\",\\"example\\":\\"Key components such as purpose, objectives, stakeholder engagement, and risk assessment are crucial as they shape the project\\u2019s direction and success.\\"}]}", "{\\"bloom_taxonomy_level\\":\\"Understand\\",\\"criteria\\":\\"Explain the importance of agreeing on the purpose and objectives of a project.\\",\\"expectations\\":\\"Learners must provide a detailed explanation of how agreed objectives lead to successful project outcomes.\\",\\"task\\":\\"Explain why it is necessary to agree on the purpose and objectives of a project before beginning the planning process.\\",\\"benchmarking_responses\\":[{\\"grade\\":\\"fail\\",\\"example\\":\\"Agreeing on the purpose is good.\\"},{\\"grade\\":\\"pass\\",\\"example\\":\\"It is important to agree on the purpose to know what to do.\\"},{\\"grade\\":\\"merit\\",\\"example\\":\\"Agreeing on the purpose and objectives aligns team efforts, ensuring everyone knows what the project aims to achieve.\\"},{\\"grade\\":\\"distinction\\",\\"example\\":\\"Agreeing on the project\\u2019s purpose and objectives is vital as it enhances clarity, aligns team efforts, motivates stakeholders, and serves as a benchmark for evaluating project success.\\"}]}", "{\\"bloom_taxonomy_level\\":\\"Apply\\",\\"criteria\\":\\"Demonstrate the ability to identify potential project issues and risks.\\",\\"expectations\\":\\"Learners must correctly identify specific risks and issues relevant to a project scenario, effectively applying knowledge to new settings.\\",\\"task\\":\\"Identify potential issues and risks in a provided project scenario you might encounter during planning.\\",\\"benchmarking_responses\\":[{\\"grade\\":\\"fail\\",\\"example\\":\\"There could be problems in a project.\\"},{\\"grade\\":\\"pass\\",\\"example\\":\\"Possible issues might be missing deadlines or resources.\\"},{\\"grade\\":\\"merit\\",\\"example\\":\\"In the given scenario, risks include resource shortages and unexpected stakeholder changes that could affect timelines.\\"},{\\"grade\\":\\"distinction\\",\\"example\\":\\"The project may face risks such as budgetary constraints, inadequate stakeholder engagement, and changing market conditions, which could significantly impact project delivery.\\"}]}", "{\\"bloom_taxonomy_level\\":\\"Analyze\\",\\"criteria\\":\\"Analyze the impact of issues and risks on a project\'s progress.\\",\\"expectations\\":\\"Learners must offer insight into how identified risks could impact various aspects of project management.\\",\\"task\\":\\"Analyze the potential impact of risks and issues identified in a project on its overall success.\\",\\"benchmarking_responses\\":[{\\"grade\\":\\"fail\\",\\"example\\":\\"Problems can make the project late.\\"},{\\"grade\\":\\"pass\\",\\"example\\":\\"If there are issues, the project may take longer.\\"},{\\"grade\\":\\"merit\\",\\"example\\":\\"Issues like resource shortages can lead to delays and increased costs, impacting project deliverables.\\"},{\\"grade\\":\\"distinction\\",\\"example\\":\\"Identified issues such as budget overruns or stakeholder disengagement can lead to project delays, financial loss ...

# %%
## Convert marksscheme to json object
[res.update({'marksscheme': [json.loads(i) for i in ast.literal_eval(res['marksscheme'])]}) for res in ofqual_results]
# Out:
# [None, None, None, None, None]

# %%
criterias = ofqual_results[0]['marksscheme']

# %%
level='Remember'
if level:
    level_based_marks_scheme = [item for item in criterias if item['bloom_taxonomy_level'] == level][0]
    criteria     = level_based_marks_scheme['criteria']
    expectations = level_based_marks_scheme['expectations']
    task         = level_based_marks_scheme['task']

    benchmarking_responses = level_based_marks_scheme['benchmarking_responses']
    benchmarking_responses = "\n\n".join([f"   **{item['grade'].upper()}:** {item['example']}" for item in benchmarking_responses])
    
    
    ofqual_based_instructions = (
        # f"- **Assessment Area:** {competency_to_assess['assessment_area']}\n\n"
        f"- **Current Bloom's Taxonomy Level mapped to User facing scale is:** {level} (But While addressing about the level, use the level in User facing scale)\n\n"
        f"- **Criteria:** {criteria}\n\n"
        f"- **Task:** {task}\n\n"
        f"- **Expectations:** {expectations}\n\n"
        f"- **Benchmarking Responses for validation:** \n\n{benchmarking_responses}\n\n"
    )

# %%
print(ofqual_based_instructions)
# Out:
# - **Current Bloom's Taxonomy Level mapped to User facing scale is:** Remember (But While addressing about the level, use the level in User facing scale)
#
# - **Criteria:** Recall the procedures for identifying and agreeing the work to be estimated with clients.
#
# - **Task:** List the steps involved in identifying and agreeing costs with clients in facility management.
#
# - **Expectations:** Learners must accurately list the steps involved in the estimation process, demonstrating knowledge of key procedures and terminologies without providing detailed explanations.
#
# - **Benchmarking Responses for validation:**
#
#    **FAIL:** The steps are not clear.
#
#    **PASS:** 1. Meet with the client 2. Discuss costs 3. Finalize the agreement.
#
#    **MERIT:** 1. Meet with the client to understand their needs 2. Discuss the scope of work 3. Identify resources needed 4. Agree on the costs based on discussions.
#
#    **DISTINCTION:** 1. Schedule an initial meeting with the client to discuss their requirements. 2. Outline the scope of work efficiently to ensure all parties have the same understanding. 3. Conduct a thorough analysis of required resources based on technical and legislative guidelines. 4. Finalize and document the cost agreement, ensuring all stakeholders approve the terms.
